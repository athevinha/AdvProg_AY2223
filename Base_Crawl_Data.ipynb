# %% [markdown]
# <a href="https://colab.research.google.com/github/athevinha/AdvProg_AY2223/blob/master/Base_Crawl_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade binance-historical-data plotly -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.9 MB/s eta 0:00:00

# %%
import os
import warnings
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from datetime import datetime, timedelta, date, time
from binance_historical_data import BinanceDataDumper
warnings.filterwarnings('ignore')

# %%
def get_list_all_trading_pairs():
    data_dumper = BinanceDataDumper(
        path_dir_where_to_dump=".",
        asset_class="spot",
        data_type="klines",
        data_frequency="1h",
    )
    return data_dumper.get_list_all_trading_pairs()

def filter_usdt_tickers(tickers):
    exclude_keywords = ["UPUSDT", "DOWNUSDT", "BEARUSDT", "BULLUSDT"]
    return [ticker for ticker in tickers if ticker.endswith("USDT") and not any(ex in ticker for ex in exclude_keywords)]

def find_first_data_date(ticker):
    data_dumper = BinanceDataDumper(
        path_dir_where_to_dump=".",
        asset_class="spot",
        data_type="klines",
        data_frequency="1h",
    )
    return data_dumper.get_min_start_date_for_ticker(ticker)

def format_time(seconds):
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    secs = int(seconds % 60)
    return f"{hours:02d}:{minutes:02d}:{secs:02d}"

def detect_timestamp_unit(timestamp):
    num_digits = len(str(timestamp))
    if num_digits == 13:
        return 'ms'
    elif num_digits == 16:
        return 'us'
    else:
        raise ValueError(f"Timestamp không hợp lệ: {timestamp}")

def convert_timestamp(timestamp):
    unit = detect_timestamp_unit(timestamp)
    return pd.to_datetime(timestamp, unit=unit, errors='coerce')

def download_ticker(ticker, date_start, date_end, data_frequency="1h"):
    data_dumper = BinanceDataDumper(
        path_dir_where_to_dump=".",
        asset_class="spot",
        data_type="klines",
        data_frequency= data_frequency,
    )
    date_start = datetime.strptime(date_start, "%Y-%m-%d").date()
    date_end = datetime.strptime(date_end, "%Y-%m-%d").date()
    data_dumper.dump_data(
        tickers = ticker,
        date_start = date_start,
        date_end = date_end,
        is_to_update_existing = False,
    )

def read_csv_file(file_path):
    df = pd.read_csv(file_path)
    df.columns = [
        "open_time", "Open", "High", "Low", "Close", "volume",
        "close_time", "quote_asset_volume", "number_of_trades",
        "taker_buy_base_asset_volume", "taker_buy_quote_asset_volume", "ignore"
    ]
    df['open_time'] = df['open_time'].apply(convert_timestamp)
    df['close_time'] = df['close_time'].apply(convert_timestamp)
    return df

def get_csv_files(directory):
    try:
        if not os.path.exists(directory):
            print(f"Warning: Thư mục không tồn tại: {directory}")
            return []
        return [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.csv')]
    except Exception as e:
        print(f"Lỗi khi đọc thư mục {directory}: {str(e)}")
        return []

# Load data from file
def process_csv_files(ticker, data_frequency = "1h"):
    daily_path = os.path.join(os.getcwd(), f"spot/daily/klines/{ticker}/{data_frequency}")
    monthly_path = os.path.join(os.getcwd(), f"spot/monthly/klines/{ticker}/{data_frequency}")
    daily_files = get_csv_files(daily_path)
    monthly_files = get_csv_files(monthly_path)
    all_files = daily_files + monthly_files
    if not all_files:
        print(f"❗ Không có file CSV nào cho {ticker}")
        return None
    data = pd.concat([read_csv_file(file) for file in all_files], ignore_index=True)
    data.sort_values(by='open_time', inplace=True)
    return data

# %%
ticker = 'BTCUSDT'
data_frequency = '1m'
download_ticker(ticker, "2025-09-01", "2025-09-22", data_frequency)
data = process_csv_files(ticker, data_frequency)
data = data.drop(columns=['close_time',	'quote_asset_volume',	'number_of_trades',	'taker_buy_base_asset_volume',	'taker_buy_quote_asset_volume',	'ignore'])
data
# Out:
# ---> Found overall tickers: 612
# ---> Filter to asked tickers: 7
# ------> Tickers left: 2
# Download full data for 2 tickers:
# ---> Data will be saved here: /content/spot
# ---> Data Frequency: 1m
# ---> Start Date: 20250901
# ---> End Date: 20250922
# Tickers:   0%|          | 0/2 [00:00<?, ?it/s]
# daily files to download:   0%|          | 0/22 [00:00<?, ?files/s]
# daily files to download: 0files [00:00, ?files/s]
# Tried to dump data for 2 tickers:
# ---> For BTCUSDT new data saved for: 0 months 22 days
# ---> For BTCUSD new data saved for: 0 months 0 days
# Warning: Thư mục không tồn tại: /content/spot/monthly/klines/BTCUSDT/1m
#                 open_time       Open       High        Low      Close  \
# 17268 2025-09-01 00:01:00  108260.00  108332.35  108259.99  108332.35
# 17269 2025-09-01 00:02:00  108332.35  108332.35  108256.43  108256.44
# 17270 2025-09-01 00:03:00  108256.44  108282.43  108229.17  108229.18
# 17271 2025-09-01 00:04:00  108229.18  108229.18  108100.00  108100.00
# 17272 2025-09-01 00:05:00  108100.00  108110.46  108060.00  108070.04
# ...                   ...        ...        ...        ...        ...
# 7190  2025-09-22 23:55:00  112628.08  112628.09  112600.00  112600.01
# 7191  2025-09-22 23:56:00  112600.01  112634.79  112600.00  112634.79
# 7192  2025-09-22 23:57:00  112634.79  112634.79  112630.41  112630.42
# 7193  2025-09-22 23:58:00  112630.41  112667.21  112630.41  112667.21
# 7194  2025-09-22 23:59:00  112667.21  112667.21  112650.98  112650.99
#
#          volume
# 17268  12.94030
# 17269  25.92896
# 17270  18.99223
# 17271  12.05048
# 17272  45.33450
# ...         ...
# 7190    1.70337
# 7191    2.47367
# 7192    1.99428
# 7193    4.76783
# 7194    1.65372
#
# [31658 rows x 6 columns]

# %%
df = data.copy()

# OHLC Chart
fig = go.Figure(
    data=[
        go.Candlestick(
            x=df["open_time"],
            open=df["Open"],
            high=df["High"],
            low=df["Low"],
            close=df["Close"],
            name="OHLC"
        )
    ]
)

# Layout config
fig.update_layout(
    title="OHLC Chart",
    xaxis_title="Time",
    yaxis_title="Price",
    xaxis_rangeslider_visible=False,
    template="plotly_dark",
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="f1a56d03-1e4c-4536-8d63-e3c4a8c99b96" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f1a56d03-1e4c-4536-8d63-e3c4a8c99b96")) {                    Plotly.newPlot(                        "f1a56d03-1e4c-4536-8d63-e3c4a8c99b96",                        [{"close":{"dtype":"f8","bdata":"mpmZmcVy+kCkcD0KB276QBSuR+FSbPpAAAAAAEBk+kA9CtejYGL6QHE9CtenYvpAFK5H4YZn+kAfhetRXGD6QD0K16NQXfpAmpmZmUFf+kAAAAAAfF76QGZmZmY6XvpAH4XrUexc+kD2KFyPKlz6QAAAAAD0X\u002fpAcT0K179e+kBxPQrXQ136QClcj8KdW\u002fpAAAAAANBa+kApXI\u002fC9Vf6QMP1KFyvUvpApHA9CqNS+kC4HoXrAVL6QJqZmZnlTvpAZmZmZppJ+kAfhetRVEj6QI\u002fC9SgATPpAcT0K179S+kDD9Shc+1L6QAAAAACoVPpAj8L1KOBO+kBxPQrXJ1X6QHE9CtezUvpAcT0K1wNQ+kAK16NwxU36QHE9CtebT\u002fpAuB6F6wFS+kBcj8L1fE\u002f6QPYoXI+OT\u002fpApHA9Ct9U+kBxPQrXv1z6QKRwPQrbaPpAhetRuB5r+kBmZmZmcmj6QHE9Cte\u002fa\u002fpAcT0K1790+kBxPQrXH2\u002f6QFyPwvVca\u002fpAhetRuI5o+kCPwvUo3GX6QClcj8LVa\u002fpArkfhesBr+kAAAAAAgHT6QClcj8JtcvpAj8L1KLRx+kD2KFyPJnb6QIXrUbhGbvpAH4XrUSBx+kC4HoXr5Wv6QAAAAACAavpAcT0K1z9u+kBI4XoU4nL6QBSuR+EGcPpA16NwPdZu+kApXI\u002fCpXP6QJqZmZm1bvpA7FG4Hi1p+kCuR+F64GT6QClcj8KxYPpACtejcAFc+kDD9Shcs2P6QHE9CtfXY\u002fpAcT0K179h+kBmZmZm+mb6QOxRuB6RY\u002fpA9ihcj55h+kCPwvUowGb6QHE9CtdjbvpASOF6FCpq+kCPwvUowGv6QB+F61EYavpAcT0K1\u002f9s+kB7FK5HAWj6QIXrUbgSZ\u002fpApHA9Cnts+kCF61G4Wm36QHE9Ctfvb\u002fpA9ihcj5Jt+kBI4XoUGm36QK5H4Xo8bfpAAAAAAIBs+kDXo3A9tmT6QHE9CtevY\u002fpAzczMzChl+kDhehSuv2P6QLgehev1bPpAj8L1KKBp+kD2KFyPKmb6QOxRuB5RavpAXI\u002fC9Vxq+kA9CtejtGf6QBSuR+EebPpA7FG4Hs1s+kA9CtejtHD6QOxRuB4Nc\u002fpAKVyPwg16+kBmZmZmtnP6QI\u002fC9SiAb\u002fpAcT0K119r+kAUrkfhFmb6QNejcD1OZvpAcT0K1+tj+kAAAAAAQF\u002f6QFK4HoVPX\u002fpAKVyPwtli+kDXo3A9ZmP6QHE9CtffZfpA7FG4Hglq+kBxPQrXY2f6QHE9CteTZ\u002fpAj8L1KPhm+kC4HoXrZWL6QAAAAAAgZ\u002fpArkfherRk+kDD9Shcd2b6QB+F61EoaPpA9ihcj1pq+kAUrkfhOmf6QDMzMzOLZvpAj8L1KABe+kCPwvUowFz6QOF6FK77WvpArkfhesxZ+kAK16NwKVz6QOF6FK7\u002fWPpAFK5H4W5a+kAAAAAAsFf6QEjhehRKWfpAj8L1KPxW+kBSuB6Fz1T6QAAAAADAVfpASOF6FD5W+kAzMzMz\u002f1L6QM3MzMxUT\u002fpAcT0K1+9C+kAfhetRJEb6QHE9CtefSfpA16NwPd5O+kCkcD0Kg0r6QLgehetRRvpAj8L1KPRD+kBxPQrXS0H6QLgehetlR\u002fpA7FG4HilD+kCuR+F68EP6QK5H4XrwQvpAH4XrUWxG+kAK16NwsUX6QIXrUbiSRPpA4XoUrs9F+kBxPQrXs0T6QKRwPQqDQ\u002fpAH4XrUWRC+kBcj8L1qEL6QMP1KFw3QvpAj8L1KLRA+kAzMzMzD0L6QOxRuB75QPpAj8L1KEA8+kBI4XoUWj36QI\u002fC9SggOvpAj8L1KMA\u002f+kBcj8L1qEH6QI\u002fC9SgkRfpAXI\u002fC9ZxM+kDhehSu\u002f0X6QB+F61GARPpApHA9CiNH+kDNzMzMEEb6QHsUrkelQfpAhetRuLI\u002f+kD2KFyPbkX6QI\u002fC9SjASfpApHA9CmtK+kCamZmZfUz6QJqZmZmBTvpAj8L1KPxJ+kCPwvUowEj6QI\u002fC9ShwSPpAMzMzMzdF+kBcj8L1kEX6QI\u002fC9SiMQvpApHA9Cs9D+kDsUbgepUD6QDMzMzMfQfpAuB6F621D+kAzMzMzB0b6QK5H4XoMR\u002fpA4XoUri9A+kDsUbgeqT76QDMzMzMXPvpArkfhekxB+kAUrkfhoj76QDMzMzN3O\u002fpAUrgehZc8+kDXo3A9gj36QArXo3BlPPpAPQrXozQ++kDD9ShcEz\u002f6QOF6FK4rQfpArkfheqw\u002f+kBcj8L1qDz6QHE9Ctc7O\u002fpAzczMzBw6+kCPwvUoADn6QHE9CtcHOvpA7FG4HgU8+kCuR+F6CD76QPYoXI+uPfpApHA9Crs\u002f+kDhehSupz\u002f6QPYoXI+eP\u002fpA7FG4Hu1A+kA9CtejSEL6QB+F61F8QvpAAAAAACBF+kCamZmZAUP6QAAAAAAAQfpAcT0K1789+kCF61G4ckD6QOxRuB4hPfpAZmZmZnI9+kDhehSuy0H6QHE9Cte7Q\u002fpAH4XrUSxJ+kAfhetRbEr6QAAAAACMSvpAcT0K159K+kCPwvUowEj6QI\u002fC9SjwRvpA4XoUrj9F+kAUrkfhakX6QHsUrke9Q\u002fpAj8L1KDBE+kAAAAAAPEH6QOF6FK7zQPpAcT0K109B+kApXI\u002fCQUT6QK5H4XpwTPpAexSuR5VK+kDNzMzMrEv6QHE9CtebS\u002fpAPQrXo1BM+kBSuB6FH036QClcj8KVTfpAAAAAAGBL+kAzMzMz70j6QClcj8I9SPpA4XoUrutF+kCPwvUoYEX6QFK4HoW3QvpAj8L1KLBA+kBmZmZmEkD6QArXo3C5OPpA16NwPdI2+kDNzMzMKDf6QI\u002fC9ShAOvpAhetRuBo\u002f+kCF61G4tjz6QFyPwvUoOPpAexSuRy05+kCPwvUogDj6QB+F61EANvpAw\u002fUoXHs1+kBxPQrXUzL6QMP1KFyTM\u002fpA4XoUrqsz+kBcj8L1FDb6QPYoXI\u002fmNvpAhetRuJ44+kCuR+F6VDX6QI\u002fC9SjANvpAhetRuPY0+kD2KFyP3jL6QGZmZmZmNPpAA ...
